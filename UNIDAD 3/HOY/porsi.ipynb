# %%
import os
import cv2
# Crear carpeta si no existe
Actividad4 = 'Actividad 4'
if not os.path.exists(Actividad4):
    os.makedirs(Actividad4)

# Guardar imagen
#cv2.imwrite(os.path.join(Actividad4, 'imagen.jpg'), frame)
